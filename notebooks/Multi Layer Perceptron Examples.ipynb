# %%
from __future__ import division
from deeplearning.mlp import MultiLayerPerceptron
from deeplearning.data import load_mnist, load_spirals
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Train a Multilayer Perceptron on the Spirals Dataset

# %%
X, y = load_spirals(100)

# %%
n_hidden = 100
learning_rate = .1
reg = 0
max_iter = 1000
iter_print = 100

ones = np.ones((300,1))
Xtrain = np.column_stack([X, ones])

mlp = MultiLayerPerceptron(Xtrain,n_hidden,y)
mlp.fit(learning_rate, reg, max_iter, iter_print)
y_hat, scores = mlp.predict(Xtrain)

plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y_hat, s=40, cmap=plt.cm.Spectral)
plt.title('Predicted Labels on Training Data')
plt.show()
# Out:
# iteration 0: loss: 7.20728635001
# iteration 100: loss: 0.399063882817
# iteration 200: loss: 0.299748332272
# iteration 300: loss: 0.254993410467
# iteration 400: loss: 0.226943070212
# iteration 500: loss: 0.206800447895
# iteration 600: loss: 0.19149480128
# iteration 700: loss: 0.179027713046
# iteration 800: loss: 0.168519946241
# iteration 900: loss: 0.159780133169

# %% [markdown]
# ## Train a Multilayer Perceptron on the MNIST dataset

# %%
train, test, validate = load_mnist('/Users/dganguli/src/deeplearning/data')
# Out:
# ... loading data
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.py:69: MatplotlibDeprecationWarning: The use of 0 (which ends up being the _last_ sub-plot) is deprecated in 1.4 and will raise an error in 1.5
#   mplDeprecation)

# %%
X_train = train[0] # 50,000 X 784
y_train = train[1] # 50,000 X 1
X_train = np.column_stack([X_train, np.ones((len(y_train),1))]) # for the bias 

X_test = test[0]
y_test = test[1]
X_test = np.column_stack([X_test, np.ones((len(y_test),1))])

n_hidden = 16
learning_rate = .1
reg = 1E-2
max_iter = 10000
iter_print = 1000

mlp = MultiLayerPerceptron(X_train,n_hidden,y_train)
mlp.fit(learning_rate, reg, max_iter, iter_print)
y_train_hat, scores_train = mlp.predict(X_train)
# Out:
# iteration 0: loss: 78.5267378848
# iteration 1000: loss: 5.84530969261
# iteration 2000: loss: 4.69975393557
# iteration 3000: loss: 3.84050228495
# iteration 4000: loss: 3.16016651247
# iteration 5000: loss: 2.61617612027
# iteration 6000: loss: 2.17591928275
# iteration 7000: loss: 1.8170251995
# iteration 8000: loss: 1.52365850219
# iteration 9000: loss: 1.28394684677

# %%
for k in range(25):
    plt.subplot(5,5,k)
    plt.imshow(np.reshape(X_train[k,:-1], (28,28)))
    plt.axis('off')
    plt.title(y_train_hat[k])

# %% [markdown]
# ### Visualize hidden layer weights

# %%
for k in range(mlp.W1.shape[0]):
    plt.subplot(4,4,k)
    plt.imshow(np.reshape(mlp.W1[k,:-1], (28,28)))
    plt.axis('off')

# %% [markdown]
# ### Investigate train and test error

# %%
train_err = (1 - np.sum((y_train_hat - y_train)==0)/len(y_train))*100

y_test_hat, scores_test = mlp.predict(X_test)
test_err = (1 - np.sum((y_test_hat - y_test)==0)/len(y_test))*100

print 'Train classification error rate: {}%\nTest classification error rate: {}%'.format(train_err,test_err)
# Out:
# Train classification error rate: 6.978%
# Test classification error rate: 6.6%

# %% [markdown]
# ### Visualize embedding of test data in the hidden layer

# %%
t = TSNE(verbose=50)
embedding = t.fit_transform(mlp.hidden_layer(X_test))
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.603519
# [t-SNE] Iteration 10: error = 28.1497046, gradient norm = 0.0031995
# [t-SNE] Iteration 20: error = 28.2943146, gradient norm = 0.0261637
# [t-SNE] Iteration 30: error = 27.5919882, gradient norm = 0.0389645
# [t-SNE] Iteration 40: error = 25.3388520, gradient norm = 0.0436510
# [t-SNE] Iteration 50: error = 24.5726600, gradient norm = 0.0444409
# [t-SNE] Iteration 60: error = 21.9161329, gradient norm = 0.0245733
# [t-SNE] Iteration 70: error = 20.8365478, gradient norm = 0.0191723
# [t-SNE] Iteration 80: error = 20.5573515, gradient norm = 0.0276491
# [t-SNE] Iteration 90: error = 20.5287632, gradient norm = 0.0351893
# [t-SNE] Iteration 100: error = 20.6236266, gradient norm = 0.0396845
# [t-SNE] Error after 100 iterations with early exaggeration: 20.623627
# [t-SNE] Iteration 110: error = 3.3941723, gradient norm = 0.0050975
# [t-SNE] Iteration 120: error = 3.2234864, gradient norm = 0.0021482
# [t-SNE] Iteration 130: error = 3.1473596, gradient norm = 0.0017743
# [t-SNE] Iteration 140: error = 3.1081515, gradient norm = 0.0016667
# [t-SNE] Iteration 150: error = 3.0866753, gradient norm = 0.0016205
# [t-SNE] Iteration 160: error = 3.0744608, gradient norm = 0.0015957
# [t-SNE] Iteration 170: error = 3.0673617, gradient norm = 0.0015814
# [t-SNE] Iteration 180: error = 3.0631845, gradient norm = 0.0015732
# [t-SNE] Iteration 190: error = 3.0607088, gradient norm = 0.0015683
# [t-SNE] Iteration 200: error = 3.0592355, gradient norm = 0.0015654
# [t-SNE] Iteration 210: error = 3.0583565, gradient norm = 0.0015636
# [t-SNE] Iteration 220: error = 3.0578313, gradient norm = 0.0015626
# [t-SNE] Iteration 230: error = 3.0575173, gradient norm = 0.0015620
# [t-SNE] Iteration 240: error = 3.0573294, gradient norm = 0.0015616
# [t-SNE] Iteration 250: error = 3.0572170, gradient norm = 0.0015614
# [t-SNE] Iteration 260: error = 3.0571497, gradient norm = 0.0015612
# [t-SNE] Iteration 270: error = 3.0571094, gradient norm = 0.0015612
# [t-SNE] Iteration 280: error = 3.0570853, gradient norm = 0.0015611
# [t-SNE] Iteration 290: error = 3.0570709, gradient norm = 0.0015611
# [t-SNE] Iteration 300: error = 3.0570622, gradient norm = 0.0015611
# [t-SNE] Iteration 310: error = 3.0570570, gradient norm = 0.0015611
# [t-SNE] Iteration 320: error = 3.0570539, gradient norm = 0.0015611
# [t-SNE] Iteration 330: error = 3.0570521, gradient norm = 0.0015611
# [t-SNE] Iteration 338: error difference 0.000000. Finished.
# [t-SNE] Error after 338 iterations: 3.057051

# %%
dat = pd.DataFrame(embedding, columns=['x','y'])
dat['label'] = y_test
plt.scatter(dat.x,dat.y,c=dat.label, s=5, cmap=mpl.cm.Set1)
plt.colorbar()
plt.show()
